# %% [markdown]
# <a href="https://colab.research.google.com/github/sreyajoga4-stack/SREYA-JOGA/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Install & Import Libraries

# %%
import pandas as pd

# %% [markdown]
# Step 2: Upload Dataset in Colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b7db3b3-7cc5-4e7d-9413-9c15d9d1f5f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b7db3b3-7cc5-4e7d-9413-9c15d9d1f5f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Step 3: Load the Dataset

# %%
df = pd.read_excel("/content/dataset.xlsx")  # use your file name

# %% [markdown]
# Step 4: View Data

# %%
df.head()
# Out:
#    OrderID  CustomerName            Email       City     Product     Category  \
# 0     1018     Amit Shah   amit@gmail.com  Ahmedabad      Laptop  Electronics
# 1     1014  Anita Sharma  anita@gmail.com  Bangalore      Laptop  Electronics
# 2     1003    Ravi Kumar   ravi@gmail.com      Delhi  Headphones  Electronics
# 3     1011    Ravi Kumar   ravi@gmail.com      Delhi  Headphones  Electronics
# 4     1015   Rahul Verma  rahul@gmail.com      Delhi      Mobile  Electronics
#
#    Quantity  Price   OrderDate
# 0         1  52000  18-01-2024
# 1         1  55000  15-01-2024
# 2         2   2000  07-01-2024
# 3         1   2000  07-01-2024
# 4         1  28000  18-01-2024

# %% [markdown]
# Step 5: Check Duplicate Rows

# %%
duplicates = df.duplicated()
print(duplicates.sum())   # number of duplicate rows
# Out:
# 0

# %% [markdown]
# Step 6: Remove Duplicate Values

# %%
df_cleaned = df.drop_duplicates()

# %% [markdown]
# Remove duplicates based on specific columns

# %%
df_cleaned = df.drop_duplicates(subset=["CustomerName", "Product", "OrderDate"])

# %% [markdown]
# Step 7: Keep First / Last Record

# %%
# keep first occurrence (default)
df_cleaned = df.drop_duplicates(keep='first')

# keep last occurrence
df_cleaned = df.drop_duplicates(keep='last')

# %% [markdown]
# Step 8: Save Cleaned Dataset

# %%
df_cleaned.to_csv("cleaned_online_retail.csv", index=False)

# %% [markdown]
# Step 9: Download File

# %%
files.download("cleaned_online_retail.csv")

# %%
df_cleaned = df.drop_duplicates(subset=["CustomerName", "Email", "Product", "OrderDate"])

# %% [markdown]
# Handle Missing Values

# %%
df.isnull().sum()
# Out:
# OrderID         0
# CustomerName    0
# Email           0
# City            0
# Product         0
# Category        0
# Quantity        0
# Price           0
# OrderDate       0
# dtype: int64

# %%
df["CustomerName"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_20741/277922612.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CustomerName"].fillna("Unknown", inplace=True)

# %%
df["Email"].fillna("noemail@gmail.com", inplace=True)
# Out:
# /tmp/ipykernel_20741/2641501903.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Email"].fillna("noemail@gmail.com", inplace=True)

# %%
df.dropna(subset=["OrderID", "Product"], inplace=True)

# %% [markdown]
# Remove Duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(subset=["CustomerName", "Product", "OrderDate"], inplace=True)

# %% [markdown]
# Standardize Text (Data Formatting)

# %%
df["CustomerName"] = df["CustomerName"].str.upper()

# %%
df["City"] = df["City"].str.title()

# %%
df["Email"] = df["Email"].str.lower()

# %% [markdown]
# Convert Data Types

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"], errors='coerce')
# Out:
# /tmp/ipykernel_20741/262411722.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["OrderDate"] = pd.to_datetime(df["OrderDate"], errors='coerce')

# %% [markdown]
# Handle Incorrect / Invalid Values

# %%
df = df[df["Quantity"] > 0]

# %%
df = df[df["Price"] > 0]

# %% [markdown]
# Save Cleaned Data

# %%
df.to_csv("cleaned_online_retail.csv", index=False)
